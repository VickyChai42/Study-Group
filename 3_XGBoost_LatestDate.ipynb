# %%
import pandas as pd

# %%
train_data = pd.read_feather("train_data.ftr")

# %%
train_data.head()
train_data.shape
# Out:
# (5531451, 190)

# %%
train_data_2 = train_data[["customer_ID","S_2","D_48", "B_18","B_2","B_9","D_44","D_75","D_55","B_33","D_58","B_7","B_3","B_23","D_74","B_4","B_16","B_1","B_19","B_37","B_20","S_7","S_3","R_3", "R_27", "R_2"]]
train_data_2.head()
# Out:
#                                          customer_ID         S_2      D_48  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09  0.255615
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07  0.223389
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28  0.189453
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13  0.135620
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16       NaN
#
#        B_18       B_2       B_9      D_44      D_75      D_55      B_33  ...  \
# 0  0.652832  1.006836  0.008209  0.000630  0.069092  0.354492  1.000977  ...
# 1  0.646973  1.000977  0.008369  0.002525  0.074158  0.326660  1.006836  ...
# 2  0.645996  1.009766  0.009354  0.007607  0.076538  0.304199  1.000977  ...
# 3  0.654297  1.002930  0.006783  0.006405  0.071533  0.275146  1.002930  ...
# 4  0.649902  1.000977  0.000519  0.007732  0.074463  0.231079  1.006836  ...
#
# ...

# %%
train_data_3 = train_data_2.sort_values(['customer_ID', 'S_2'], ascending = [True, False])
train_data_3.head()
# Out:
#                                           customer_ID         S_2      D_48  \
# 12  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2018-03-13  0.192383
# 11  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2018-02-21  0.237183
# 10  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2018-01-11  0.325684
# 9   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-12-04  0.403564
# 8   0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-11-20  0.189331
#
#         B_18       B_2       B_9      D_44      D_75      D_55      B_33  ...  \
# 12  1.007812  1.007812  0.009537  0.003258  0.001352  0.187256  1.007812  ...
# 11  1.004883  1.008789  0.001063  0.005108  0.009682  0.196533  1.003906  ...
# 10  1.006836  1.004883  0.006718  0.002390  0.009895  0.194214  1.005859  ...
# 9   1.007812  1.007812  0.007080  0.007595  0.004539  0.186768  1.000977  ...
# 8   1.007812  1.003906  0.006821  0.002579  0.000035  0.160034  1.002930  ...
#
# ...

# %%
train_data_4 = train_data_3.drop_duplicates(subset=["customer_ID"], keep="first")
train_data_4.head()
# Out:
#                                           customer_ID         S_2      D_48  \
# 12  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2018-03-13  0.192383
# 25  00000fd6641609c6ece5454664794f0340ad84dddce9a2...  2018-03-25  0.014694
# 38  00001b22f846c82c51f6e3958ccd81970162bae8b007e8...  2018-03-12  0.080383
# 51  000041bdba6ecadd89a52d11886e8eaaec9325906c9723...  2018-03-29       NaN
# 64  00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8a...  2018-03-30  0.325195
#
#         B_18       B_2       B_9      D_44      D_75      D_55      B_33  ...  \
# 12  1.007812  1.007812  0.009537  0.003258  0.001352  0.187256  1.007812  ...
# 25  1.003906  1.003906  0.012924  0.008781  0.009598  0.036102  1.000977  ...
# 38  1.003906  0.812500  0.009392  0.000628  0.003328  0.098938  1.000977  ...
# 51  1.006836  1.005859  0.020523  0.007793  0.005505  0.021393  1.009766  ...
# 64  0.531250  0.815918  0.004028  0.002436  0.142578  0.254150  1.007812  ...
#
# ...

# %%
train_data_4.shape
# Out:
# (458913, 26)

# %%
train_data_label = pd.read_csv("train_labels.csv")
train_data_label.head()
# Out:
#                                          customer_ID  target
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...       0
# 1  00000fd6641609c6ece5454664794f0340ad84dddce9a2...       0
# 2  00001b22f846c82c51f6e3958ccd81970162bae8b007e8...       0
# 3  000041bdba6ecadd89a52d11886e8eaaec9325906c9723...       0
# 4  00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8a...       0

# %%
train_data_final = pd.merge(train_data_4,train_data_label,how="left",on="customer_ID")

# %%
train_data_final.head()
# Out:
#                                          customer_ID         S_2      D_48  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2018-03-13  0.192383
# 1  00000fd6641609c6ece5454664794f0340ad84dddce9a2...  2018-03-25  0.014694
# 2  00001b22f846c82c51f6e3958ccd81970162bae8b007e8...  2018-03-12  0.080383
# 3  000041bdba6ecadd89a52d11886e8eaaec9325906c9723...  2018-03-29       NaN
# 4  00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8a...  2018-03-30  0.325195
#
#        B_18       B_2       B_9      D_44      D_75      D_55      B_33  ...  \
# 0  1.007812  1.007812  0.009537  0.003258  0.001352  0.187256  1.007812  ...
# 1  1.003906  1.003906  0.012924  0.008781  0.009598  0.036102  1.000977  ...
# 2  1.003906  0.812500  0.009392  0.000628  0.003328  0.098938  1.000977  ...
# 3  1.006836  1.005859  0.020523  0.007793  0.005505  0.021393  1.009766  ...
# 4  0.531250  0.815918  0.004028  0.002436  0.142578  0.254150  1.007812  ...
#
# ...

# %%
X_train = train_data_final[["customer_ID", "D_48", "B_18","B_2","B_9","D_44","D_75","D_55","B_33","D_58","B_7","B_3","B_23","D_74","B_4","B_16","B_1","B_19","B_37","B_20","S_7","S_3","R_3", "R_27", "R_2"]]
X_train.isnull().sum()
# Out:
# customer_ID        0
# D_48           57992
# B_18               0
# B_2               31
# B_9                0
# D_44           22295
# D_75               0
# D_55           30377
# B_33              31
# D_58               0
# B_7                0
# B_3               31
# B_23               0
# D_74            1701
# B_4                0
# B_16              31
# B_1                0
# B_19              31
# B_37               0
# B_20              31
# S_7            84970
# S_3            84970
# R_3                0
# R_27           28736
# R_2                0
# dtype: int64

# %%
# !pip install xgboost
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.9/192.9 MB 13.4 MB/s eta 0:00:0000:0100:01
# ...

# %%
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X_train_final = X_train[["D_48", "B_18","B_2","B_9","D_44","D_75","D_55","B_33","D_58","B_7","B_3","B_23","D_74","B_4","B_16","B_1","B_19","B_37","B_20","S_7","S_3","R_3", "R_27", "R_2"]]
y_train = train_data_final[["target"]]

model = XGBClassifier()
model.fit(X_train_final, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
test_data = pd.read_feather("test_data.ftr")

# %%
test_data_1 = test_data[["customer_ID", "S_2", "D_48", "B_18","B_2","B_9","D_44","D_75","D_55","B_33","D_58","B_7","B_3","B_23","D_74","B_4","B_16","B_1","B_19","B_37","B_20","S_7","S_3","R_3", "R_27", "R_2"]].sort_values(['customer_ID', 'S_2'], ascending = [True, False])
test_data_2 = test_data_1.drop_duplicates(subset=["customer_ID"], keep="first")
test_data_2.isnull().sum()
# Out:
# customer_ID         0
# S_2                 0
# D_48           116986
# B_18                0
# B_2                43
# B_9                 0
# D_44            44612
# D_75                0
# D_55            60438
# B_33               43
# D_58                0
# B_7                 0
# B_3                43
# B_23                0
# D_74             4179
# B_4                 0
# B_16               43
# B_1                 0
# B_19               43
# B_37              834
# B_20               43
# S_7            144280
# S_3            144280
# R_3                 0
# R_27            51391
# R_2                 0
# dtype: int64

# %%
test_out_1 = model.predict_proba(test_data_2[["D_48", "B_18","B_2","B_9","D_44","D_75","D_55","B_33","D_58","B_7","B_3","B_23","D_74","B_4","B_16","B_1","B_19","B_37","B_20","S_7","S_3","R_3", "R_27", "R_2"]])
test_out_1
# Out:
# array([[0.96538025, 0.03461972],
#        [0.9984323 , 0.00156772],
#        [0.95663166, 0.04336835],
#        ...,
#        [0.45179135, 0.54820865],
#        [0.6723351 , 0.3276649 ],
#        [0.9914613 , 0.00853875]], dtype=float32)

# %%
test_out_2 = pd.DataFrame(test_out_1,columns=["1_minus_pred","prediction"])
test_out_2.head()
# Out:
#    1_minus_pred  prediction
# 0      0.965380    0.034620
# 1      0.998432    0.001568
# 2      0.956632    0.043368
# 3      0.639343    0.360657
# 4      0.071620    0.928380

# %%
X_test_2 = test_data_2[["customer_ID"]]

cus = X_test_2["customer_ID"].reset_index()
pred = test_out_2["prediction"]

test_out_3 = pd.concat([cus["customer_ID"],pred],ignore_index=True,axis=1)
test_out_3.rename(columns = {0:'customer_ID', 1:'prediction'}, inplace = True)

test_out_3.head()
# Out:
#                                          customer_ID  prediction
# 0  00000469ba478561f23a92a868bd366de6f6527a684c9a...    0.034620
# 1  00001bf2e77ff879fab36aa4fac689b9ba411dae63ae39...    0.001568
# 2  0000210045da4f81e5f122c6bde5c2a617d03eef67f82c...    0.043368
# 3  00003b41e58ede33b8daf61ab56d9952f17c9ad1c3976c...    0.360657
# 4  00004b22eaeeeb0ec976890c1d9bfc14fd9427e98c4ee9...    0.928380

# %%
test_out_3.to_csv("Submission_XGboost_LatestDate.csv", index=False)

# %%
# !kaggle competitions submit -c amex-default-prediction -f Submission_XGboost_LatestDate.csv -m "Message"
# Out:
# ...
# 100%|██████████████████████████████████████| 67.5M/67.5M [00:04<00:00, 14.6MB/s]
# Successfully submitted to American Express - Default Prediction
